# %%
from src.pyfsrs.wcard import WCard

# %% [markdown]
# Add new word card

# %%
wc = WCard(word="management", lang="en")
print(wc.to_dict())
wc.save_to_supabase()
# Out:
# c:\Users\eskan\miniconda3\envs\jvd310\lib\site-packages\rich\live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Raw collocations: Here are some common collocations for the word 'management' in English, categorized by their patterns:
#
# **Adjective + Noun:**
# - active management
# - adaptive management
# - capital management
# - careful management
# - centralized management
#
# **Noun + Noun:**
# - classroom management
# - clinical management
# - competent management
# - comprehensive management
# - conflict management
#
# **Verb + Noun:**
# - need management
# - perform management
# - handle management
# - be responsible for management
# - enhance management
#
# **Noun + Verb:**
# - management needs
# - management performs
# - management handles
# ...

# %% [markdown]
# get the word card

# %%
# new_wc = WCard.from_supabase(id="938381ec-2cf4-4aa3-8fc5-cae26768215f")
# print(new_wc.to_dict())
